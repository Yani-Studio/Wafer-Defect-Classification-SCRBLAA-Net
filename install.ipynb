# %%
# !pip install scikit-image scipy

# %%
# 주피터 노트북 내부 셀에서 실행 시 (pip 버전)
# !pip install torch torchvision torchaudio scikit-image scipy

# %%
# !pip install opencv-python

# %%
# !pip install tqdm
